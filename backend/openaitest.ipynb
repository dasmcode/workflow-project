# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI()

response = client.responses.create(
    model="gpt-5.4",
    input="How much gold would it take to coat the Statue of Liberty in a 1mm layer?",
    reasoning={"effort": "none"},
)

print(response.output[0].content[0].text)
# Out:
# Treat the statue’s outside as roughly **4,000 m²** of surface area (a commonly cited figure for the copper skin).
#
# A **1 mm** gold layer is:
#
# - \(1 \text{ mm} = 0.001 \text{ m}\)
#
# ### 1) Volume of gold needed
# \[
# V = \text{area} \times \text{thickness}
# = 4000 \times 0.001
# = 4 \text{ m}^3
# \]
#
# ### 2) Convert volume to mass
# Gold’s density is about:
#
# - \(19{,}300 \text{ kg/m}^3\)
#
# So:
#
# \[
# m = 4 \times 19{,}300 = 77{,}200 \text{ kg}
# \]
#
# ### 3) In tons
# \[
# 77{,}200 \text{ kg} \approx 77.2 \text{ metric tons}
# \]
#
# ## Answer
# It would take about **77 metric tons of gold** to coat the Statue of Liberty in a **1 mm** layer.
#
# If you want, I can also estimate the **dollar value** at current gold prices.

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance
client = QdrantClient(host="localhost", port=6333)

if client.collection_exists("test"):
    print("Collection 'test' already exists.")
else:
    client.create_collection(
        collection_name="test",
        vectors_config=VectorParams(size=1024, distance=Distance.COSINE),
    )
# Out:
# Collection 'test' already exists.

# %%
import uuid
job_id = str(uuid.uuid4())
job_id
# Out:
# '79812b7c-f83c-49d7-b1d2-94c32ee4cc8b'

# %%
point_id = str(uuid.uuid5(uuid.NAMESPACE_DNS, f"{job_id}_1"))
point_id
# Out:
# '1f561785-7ac3-5da4-962b-24f2b222c33a'
